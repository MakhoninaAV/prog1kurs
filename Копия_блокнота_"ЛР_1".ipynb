# %% [markdown]
# <a href="https://colab.research.google.com/github/MakhoninaAV/prog1kurs/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%9B%D0%A0_1%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_01_01.
""" Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
•	арифметические: +, -, * , / , // , %, **;
•	сравнение: <, <=, >, >=, !=, ==,
выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).
"""
# Выполнил: Махонина А. В.
# Группа: ЦИБ-241


a = int(input("a="))
b = int(input("b="))

print(a + b)
print(a - b)
print(a * b)
print(round((a / b), 2))
print(a // b)
print(a % b)
print(a ** b)

print(a < b)
print(a <= b)
print(a > b)
print(a >= b)
print(a != b)
print(a == b)


# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False

# %% [markdown]
# 01_01: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип int, выполнять арифметические операции (сложение, вычитание, умножение, деление, целочисленное деление, остаток от деления, возведение в степень) и применять операторы сравнения (<, <=, >, >=, !=, ==). Также я освоила вывод результатов с помощью print() и округление чисел функцией round()

# %%
# Задание task_01_02.
#
# Выполнил: Махонина А. В.
# Группа: ЦИБ-241


x = int(input("x="))
y = int(input("y="))
z = int(input("z="))

res = (((x**5 + 7) / (abs(-6) * y)) ** (1/3)) / (7 - (z % y))
print(round(res,2))


# --------------
# Пример вывода:
#
# x=0
# y=1
# z=2
# 0.15
# Out:
# x=0
# y=1
# z=2
# 0.15

# %% [markdown]
# 01_02: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип int для работы с целыми числами. Я освоила выполнение сложных арифметических операций, включая возведение в степень (**), нахождение модуля числа (abs()), деление (/), вычисление остатка от деления (%), а также применение корня через возведение в дробную степень. Научилась комбинировать эти операции в сложных выражениях, соблюдая порядок выполнения, и округлять результат с помощью функции round() до двух знаков после запятой

# %%
# Задание task_01_03.
#
# Выполнил: Махонина А. В.
# Группа: ЦИБ-241


# Сопротивление первого проводника
r1 = float(input("r1="))
# Сопротивление второго проводника
r2 = float(input("r2="))
# Общее сопротивление
r = r1 + r2
print(round(r, 1))


# --------------
# Пример вывода:
#
# r1=12.2
# r2=16.1
# 28.3
# Out:
# r1=12.2
# r2=16.1
# 28.3

# %% [markdown]
# 01_03: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип float для работы с вещественными числами, что позволяет учитывать дробные значения сопротивлений. Я освоила выполнение арифметической операции сложения (+) для вычисления общего сопротивления двух проводников, соединенных последовательно, и округление результата с помощью функции round() до одного знака после запятой

# %%
# Задание task_01_04.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241


# Двузначное число
num2 = int(input("Двузначное число: "))
# Трехзначное число
num3 = int(input("Трехзначное число: "))

# 1-я цифра числа 'num2'
num2_1 = num2//10
# 2-я цифра числа 'num2'
num2_2 = num2%10

# Сумма цифр числа 'num2'
num2_s = num2_1 + num2_2
# Произведение цифр числа 'num2'
num2_p = num2_1 * num2_2

# 1-я цифра числа 'num3'
num3_1 = num3//100
# 2-я цифра числа 'num3'
num3_2 = ((num3//10)%10)
# 3-я цифра числа 'num3'
num3_3 = num3%10

# Сумма цифр числа 'num3'
num3_s = num3_1 + num3_2 + num3_3
# Произведение цифр числа 'num3'
num3_p = num3_1 * num3_2 * num3_3

# Вывод результата
print("Сумма и произведение цифр двузначного числа:", num2_s, num2_p)
print("Сумма и произведение цифр трехзначного числа:", num3_s, num3_p)


# --------------
# Пример вывода:
#
# Двузначное число: 45
# Трехзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трехзначного числа: 15 120
# Out:
# Двузначное число: 45
# Трехзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трехзначного числа: 15 120

# %% [markdown]
# 01_04: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип int для работы с целыми числами, что позволяет обрабатывать двузначные и трехзначные числа. Я освоила операции целочисленного деления (//) и нахождения остатка от деления (%) для выделения отдельных цифр из чисел, а также выполнение арифметических операций сложения (+) и умножения (*) для вычисления суммы и произведения цифр

# %%
# Задание task_01_05.
#
# Выполнил: Махонина А. В.
# Группа: ЦИБ-241


# Количество минут, прошедшее с начала суток
m = int(input("Количество минут, прошедшее с начала суток: "))
# Количество часов, прошедших с начала суток
h = m//60
# Количество минут, прошедших с момента начала последнего часа
m2 = m%60

print("Количество часов, прошедших с начала суток:", h)
print("Количество минут, прошедших с момента начала последнего часа", m2)


# --------------
# Пример вывода:
#
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа: 3
# Out:
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа 3

# %% [markdown]
# 01_05: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип int для работы с целыми числами, что позволяет обрабатывать количество минут, прошедших с начала суток. Я освоила операции целочисленного деления (//) для вычисления количества часов и нахождения остатка от деления (%) для определения минут, прошедших с начала последнего часа. Использовала функцию print() для вывода результатов

# %%
# Задание task_01_06.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241


a = int(input("Введите a = "))
b = int(input("Введите b = "))
m = int(input("Введите m = "))
n = int(input("Введите n = "))

x = -b / a

is_ok = bool(m <= x <= n )

print("Попадает:", is_ok)


# --------------
# Пример вывода:
#
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True
# Out:
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True

# %% [markdown]
# 01_06: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и преобразовывать их в тип int для работы с целыми числами, что позволяет обрабатывать введенные пользователем значения a, b, m и n. Я освоила выполнение арифметической операции деления (/) для нахождения значения x как решения уравнения ax + b = 0, а также использование логического выражения с операторами сравнения (<=) для проверки, попадает ли x в заданный диапазон от m до n. Научилась преобразовывать результат логического выражения в тип bool с помощью функции bool(), что возвращает True или False, и использовать функцию print() для вывода результата

# %%
# Задание task_01_07.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241


team = input("Введите название команды: ")

print(team,"- чемпион!")
k = len(team)
h = "-"
print(h*k)

# Название команды в нижнем регистре
team_lowercase = team.lower()
print("Символов в названии команды:", k)
print('Буква "п" есть:', "п" in team_lowercase)
print('Количество букв "а":', team_lowercase.count("а"))


# --------------
# Пример вывода:
#
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
# Out:
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2

# %% [markdown]
# 01_07: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и работать со строковым типом данных (str), что позволяет обрабатывать название команды. Я освоила функцию len() для подсчета количества символов в строке, операцию умножения строки на число (*) для создания строки из повторяющихся символов, а также методы строк lower() для приведения текста к нижнему регистру, in для проверки наличия подстроки и count() для подсчета количества вхождений определенной буквы

# %%
# Задание task_01_08.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241


# Название государства
country = input("Введите название государства: ")
# Название столицы
capital = input("Введите название столицы: ")

print("Государство - {}, стлица - {}".format(country,capital))


# --------------
# Пример вывода:
#
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва
# Out:
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, стлица - Москва

# %% [markdown]
# 01_08: В данной лабораторной работе я научилась использовать функцию input() для ввода данных и работать со строковым типом данных (str), что позволяет обрабатывать названия государства и столицы. Я освоила метод форматирования строк с помощью format(), который позволяет вставлять значения переменных в шаблон строки для создания читаемого вывода. Научилась использовать функцию print() для вывода отформатированного текста с переменными

# %%
# Задание task_01_09.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241
# E-mail: MakhoninaAV@mgpu.ru

word = "объектно-ориентированный"

w1 = word[:6]  # (слово объект)
w2 = word[9:17] # (слово ориентир)
w3 = word[14:17] #(слово тир)
w4 = word[4]+word[0]+word[5]#(слово кот)
w5 = word[10]+word[12:15]+word[19] #(слово рента)

print(w1, w2, w3, w4, w5, sep="\n")


# --------------
# Пример вывода:
#
# объект
# ориентир
# тир
# кот
# рента

# %% [markdown]
# 01_09: В данной лабораторной работе я научилась работать со строковым типом данных (str) и использовать срезы строк для выделения подстрок, например, word[:6] для получения первых шести символов. Я освоила индексацию строк для доступа к отдельным символам, а также конкатенацию символов для формирования новых слов, например, word[4] + word[0] + word[5]. Научилась использовать функцию print() с параметром sep="\n" для вывода результатов на отдельных строках

# %%
# Задание task_01_10.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241
# E-mail: MakhoninaAV@mgpu.ru


# Создать 2 пустых списка
a = list()
b = list()

# Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
a.append(4.5)
a.append(3.4)
# Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
a.extend([8.7])
a.extend([1.3])
# Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
b.append(14.5)
b.append(3.4)
# Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
b.extend([8.7])
b.extend([11.3])

# Вставить целое число 100 на 2-е и 4-е место списка 'a'
a.insert(1,100)
a.insert(3,100)

# Вставить целое число 200 на 1-е и 3-е место списка 'b'
b.insert(0,200)
b.insert(2,200)
# Вывести списки на экран
print("Исходные списки:")
print("1-й:", a)
print("2-й:", b)

# Удалить первые элементы из списков 'a' и 'b'
del a[0]
del b[0]

# Удалить элемент 100 из списка 'a'
a.remove(100)
# Удалить элемент 200 из списка 'b'
b.remove(200)


# Вывести списки на экран
print("\nПосле удалений:")
print("1-й:", a)
print("2-й:", b)

# Создать множества из списков 'a' и 'b', а также их пересечение
sa = set(a)
sb = set(b)
sa_and_sb = sa.intersection(sb)

# Вывести экран уникальные элементы каждого списка и общие
print("\nУникальные элементы:")
print("1-й:", sa)
print("2-й:", sb)
print("общие:", sa_and_sb)

# Соединить списки 'a' и 'b'
c =  a + b

# Отсортировать список 'c' по возрастанию и убыванию
c_asc = sorted(c)
c_desc = sorted(c,reverse=True)

# Среднее арифметическое элементов списка 'c', расположенных на четных местах
p = c[1::2]
sr_ar = sum(p)/len(p)
# Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
h=c[0::2]
s=h[0]*h[1]*h[2]*h[3]
sr_geom = (s**0.25)

# Максимальный и минимальный элементы
c_max = max(c)
c_min = min(c)

# Вывести результаты на экран
print("\nИтоговые:")
print("3-й:", c)
print("Сортировка (возр.):",c_asc)
print("Сортировка (убыв.):",c_desc)
print("Ср. арифм. =",round(sr_ar,3),"ср. геометр =", round(sr_geom,2))

print("Макс. и мин.:",c_max,c_min)


# --------------
# Пример вывода:
#
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.00, ср. геометр. = 7.82
# Макс. и мин.: 100 1.3
# Out:
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.0 ср. геометр = 7.82
# Макс. и мин.: 100 1.3

# %% [markdown]
# 01_10: При выполнении данного задания, я научилась работать со списками (list), создавая пустые списки и добавляя элементы с помощью методов append() и extend(), а также вставляя элементы на заданные позиции с помощью insert(). Я освоила удаление элементов из списков с помощью оператора del и метода remove(), а также объединение списков с помощью операции +. Научилась работать с множествами (set), создавая их из списков и находя пересечение с помощью метода intersection(). Я изучила сортировку списков с помощью функции sorted() по возрастанию и убыванию, а также вычисление среднего арифметического и геометрического с использованием срезов ([1::2], [0::2]), функций sum(), len() и возведения в степень (**). Научилась находить максимальный и минимальный элементы списка с помощью функций max() и min(), а также округлять результаты с помощью round()

# %%
# Задание task_01_11.
#
# Выполнил: Махонина А.В.
# Группа: ЦИБ-241
# E-mail: MakhoninaAV@mgpu.ru


# В данной задаче все значения задаются в коде (без input())

# 1. Создание словаря
# Создать пустой словарь
info = {}

# Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
info["фио"] = "Иванов Иван Иванович"
info["дата_рождения"] = "25/09/1999"
info["место_рождения"] = "Самара"


# Напечатать словарь
print(info)

# Создать ключ "хобби" со значением = список из строк -
# наименований хобби (например "плавание" и т.д.)
info["хобби"] = ["игра на гитаре", "верховая езда","шахматы"]

# Добавить "программирование" в список хобби
info["хобби"].append("программирование")

# Создать ключ "животные" со значением = кортеж из строк -
# имен домашних животных (например "кошка Мурка" и т.д.)
info["животные"] = ("кошка Мурка", "хомяк Пухля", "собака Рекс")

# Создать ключ "ЕГЭ" и поместить в него пустой словарь
info["ЕГЭ"] = {}

# В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах,
# где ключ - наименование предмета, а значение - количество баллов
info["ЕГЭ"]["Русский язык"] = 80
info["ЕГЭ"]["Математика"] = 75
info["ЕГЭ"]["Информатика"] = 90

# Добавить экзамен, который не был сдан, после чего удалить его
info["ЕГЭ"]["История"] = 20
del info["ЕГЭ"]["История"]

# Создать ключ "вузы" и поместить в него пустой словарь
info["вузы"] = {}

# В словарь info["вузы"] добавить информацию о вузах,
# где ключ - аббревиатура вуза, а значение -
# количество баллов для специальности, на которую хотели поступить
info["вузы"]["МАДИ"] = 270
info["вузы"]["МЭИ"] = 260
info["вузы"]["МПУ"] = 230

# 2. Вывод на экран
print("Данные:")
# Получившийся словарь
print(info)

# Список экзаменов ЕГЭ в алфавитном порядке
# (используйте метод ``keys()``, преобразовав результат в кортеж)
exams = tuple(sorted(info["ЕГЭ"].keys()))
print("Предметы:", exams)
# Список вузов в алфавитном порядке
uni = tuple(sorted(info["вузы"].keys()))
print("Вузы:", uni)

# 3. Ответы на вопросы
print("\nОтветы на вопросы:")

# Выделить имя из info["фио"]
name = info["фио"].split()[1]
# Начинается на гласную? (True/False)
starts_with_vowel = (name[0].lower() in "аеёиоуыэюя")
print("* Мое имя начинается на гласную букву:", starts_with_vowel)

# Выделить месяц из info ["дата_рождения"]
month = int(info["дата_рождения"].split("/")[1])
# Родился зимой или летом? (True/False)
born_in_winter_or_summer = month in ["12", "01", "02", "6", "7", "8"]
print("* Родился летом или зимой:", born_in_winter_or_summer)

# Количество хобби и первое из них
hobbies_count = len(info["хобби"])
first_hobby = info["хобби"][0]
print("* У меня {} хобби, первое \"{}\"".format(hobbies_count , first_hobby))

# Количество сданных экзаменов
ex = len(info["ЕГЭ"])
print("* После окончания школы сдавал {} экз.".format(ex))

# Сумма баллов по экзаменам
sum_mark = sum(info["ЕГЭ"].values())
print("* сумма баллов = {}".format(sum_mark))

# Максимальный балл среди сданных
max_mark = max(info["ЕГЭ"].values())
print("* макс. балл = {}".format(max_mark))

# Количество вузов, в которые Вы проходите по баллам
# Подсказка: определить, проходите Вы или нет, можно простым сравнением
# суммы баллов с проходным баллом вуза - ``True/False``.
# Для того, чтобы определить количество таких вузов, преобразуйте
# сравнение в целое число (используя ``int()``) и сложите все сравниваемые вузы.
vuz_count = sum(int(sum_mark >= passing_score) for passing_score in info["вузы"].values())
print("* Количество вузов в которые прохожу: {}".format(vuz_count))

# --------------
# Пример вывода:
#
# {'фио': 'Иванов Иван Иванович', 'место_рождения': 'Париж',
#  'дата_рождения': '01/09/1995'}
# Данные:
# {'фио': 'Иванов Иван Иванович', 'животные': ('кошка Мурка',),
#  'вузы': {'МИРЭА': 240, 'МГУ': 295, 'МГТУ им. Баумана': 255},
#  'хобби': ['игра на гитаре', 'туризм', 'программирование'],
#  'ЕГЭ': {'Математика': 90, 'Информатика': 88, 'Русский язык': 67},
#  'дата_рождения': '01/09/1995', 'место_рождения': 'Париж'}
# Предметы: Информатика, Математика, Русский язык
# Вузы: МГТУ им. Баумана, МГУ, МИРЭА

# Ответы на вопросы:
# * мое имя начинается на гласную букву: True
# * родился летом или зимой: False
# * у меня 3 хобби, первое "игра на гитаре"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 245
# * макс. балл = 90
# * кол-во вузов в которые прохожу: 1
# Out:
# {'фио': 'Иванов Иван Иванович', 'дата_рождения': '25/09/1999', 'место_рождения': 'Самара'}
# Данные:
# {'фио': 'Иванов Иван Иванович', 'дата_рождения': '25/09/1999', 'место_рождения': 'Самара', 'хобби': ['игра на гитаре', 'верховая езда', 'шахматы', 'программирование'], 'животные': ('кошка Мурка', 'хомяк Пухля', 'собака Рекс'), 'ЕГЭ': {'Русский язык': 80, 'Математика': 75, 'Информатика': 90}, 'вузы': {'МАДИ': 270, 'МЭИ': 260, 'МПУ': 230}}
# Предметы: ('Информатика', 'Математика', 'Русский язык')
# Вузы: ('МАДИ', 'МПУ', 'МЭИ')
#
# Ответы на вопросы:
# * Мое имя начинается на гласную букву: True
# * Родился летом или зимой: False
# * У меня 4 хобби, первое "игра на гитаре"
# * После окончания школы сдавал 3 экз.
# * сумма баллов = 245
# * макс. балл = 90
# * Количество вузов в которые прохожу: 1

# %% [markdown]
# 01_11: В данной лабораторной работе я научилась работать со словарями (dict), создавая пустые словари, добавляя и удаляя ключи с помощью оператора del, а также обновляя значения, включая вложенные словари. Я освоила работу со списками (list) и кортежами (tuple), добавляя элементы с помощью append(), сортируя ключи словарей с помощью sorted() и преобразовывая результаты в кортежи. Научилась обрабатывать строковые данные, используя метод split() для разделения строк, проверять условия с помощью оператора in и логических выражений, а также форматировать вывод с помощью метода format(). Я изучила работу с числовыми данными, вычисляя сумму и максимум значений словаря с помощью sum() и max(), а также определяя количество подходящих вузов с использованием генератора списков и функции int()
